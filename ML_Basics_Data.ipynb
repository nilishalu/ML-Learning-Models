# %% [markdown]
# <a href="https://colab.research.google.com/github/nilishalu/ML-Learning-Models/blob/main/ML_Basics_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/wlifferth/ghw-2023-02
# Out:
# Cloning into 'ghw-2023-02'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 21 (delta 4), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (21/21), 152.98 KiB | 2.89 MiB/s, done.

# %%
import pandas as pd

df = pd.read_csv('/content/ghw-2023-02/loan_applications.csv')

# %%
df.head()
# Out:
#        race  credit_score  zipcode  will_default
# 0  hispanic           498    71202         False
# 1     white           812    71204         False
# 2     white           604    71203          True
# 3     black           339    71207          True
# 4  hispanic           582    71205         False

# %%
df['race']
# Out:
# 0       hispanic
# 1          white
# 2          white
# 3          black
# 4       hispanic
#           ...
# 5026       white
# 5027       asian
# 5028       black
# 5029       black
# 5030       asian
# Name: race, Length: 5031, dtype: object

# %%
df.credit_score
# Out:
# 0       498
# 1       812
# 2       604
# 3       339
# 4       582
#        ...
# 5026    644
# 5027    697
# 5028    496
# 5029    666
# 5030    639
# Name: credit_score, Length: 5031, dtype: int64

# %%
df.columns
# Out:
# Index(['race', 'credit_score', 'zipcode', 'will_default'], dtype='object')

# %%
for col in df.columns:
  print(col)
# Out:
# race
# credit_score
# zipcode
# will_default

# %%
for col in df.columns:
  print(col)
  print(df[col].value_counts())
  print()
# Out:
# race
# white       1846
# asian       1224
# hispanic    1051
# black        910
# Name: race, dtype: int64
#
# credit_score
# 666    25
# 720    23
# 642    23
# 745    22
# 721    21
#        ..
# 366     2
# 465     1
# 375     1
# 413     1
# 549     1
# Name: credit_score, Length: 551, dtype: int64
#
# zipcode
# 71202    874
# 71204    711
# 71206    651
# 71200    636
# 71203    580
# 71201    550
# 71205    521
# 71207    508
# Name: zipcode, dtype: int64
#
# will_default
# False    3134
# True     1897
# Name: will_default, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 4])

# %%
plt.rcParams['figure.figsize'] = [18, 6]
plt.title("Distribution of Credit Scores")
plt.hist(df['credit_score'], bins = 40)
plt.show()

# %%
for race in sorted(df['race'].unique()):
  plt.figure(figsize = (12, 2))
  plt.title(race)
  plt.hist(df[df['race'] == race]['credit_score'], bins = 40)
  plt.show()

# %%
crosstab_results = pd.crosstab(index = df['zipcode'], columns = df['race'])
crosstab_results.plot.bar()

# %%
for zipcode in sorted(df['zipcode'].unique()):
   plt.figure(figsize = (12, 3))
   plt.title(zipcode)
   plt.hist(df[df['zipcode'] == zipcode]['credit_score'], bins = 40)
   plt.show()

# %%
import seaborn as sns

plt.title("Credit Score and Zipcode")
sns.violinplot(data = df, x = 'zipcode', y = 'credit_score')
plt.show()

# %%
import seaborn as sns

plt.title("Credit Score and Race")
sns.violinplot(data = df, x = 'race', y = 'credit_score')
plt.show()
